# %% [markdown]
# # V1 - Detector: Load Model
#
# Verifies GPU, then loads the YOLOv11s base model. RTX 2050 / 4GB VRAM - see CLAUDE.md for training defaults (batch 8, imgsz 640).

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# Device: NVIDIA GeForce RTX 2050

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")  # auto-downloads pretrained weights on first run
model.info()
# Out:
# YOLO11s summary: 181 layers, 9,458,752 parameters, 0 gradients, 21.8 GFLOPs
# (181, 9458752, 0, 21.8363392)

# %%
# %pip install roboflow --no-deps
# Out:
# ...
#   Using cached roboflow-1.4.1-py3-none-any.whl.metadata (11 kB)
# Using cached roboflow-1.4.1-py3-none-any.whl (302 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
from roboflow import Roboflow

load_dotenv()

rf = Roboflow(api_key=os.environ["ROBOFLOW_API_KEY"])
project = rf.workspace("kasera-pvt").project("pothholes-new")
dataset = project.version(1).download("yolov11", location="datasets/pothholes")

print(dataset.location)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to datasets/pothholes in yolov11:: 100%|██████████| 1604/1604 [00:02<00:00, 670.81it/s]
# c:\Users\Nitro V15\Projects\PothholeDetection\datasets\pothholes
